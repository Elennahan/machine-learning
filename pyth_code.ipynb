# %% [markdown]
# ## logistics model

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. import the data

# %%
data = pd.read_csv('heloc_dataset_v1.csv')
print(data)
# Out:
#       RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0                 Bad                    55                    144
# 1                 Bad                    61                     58
# 2                 Bad                    67                     66
# 3                 Bad                    66                    169
# 4                 Bad                    81                    333
# ...               ...                   ...                    ...
# 10454            Good                    73                    131
# 10455             Bad                    65                    147
# 10456             Bad                    74                    129
# 10457             Bad                    72                    234
# 10458             Bad                    66                     28
#
#        MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                              4              84                     20
# 1                             15              41                      2
# 2                              5              24                      9
# 3                              1              73                     28
# 4                             27             132                     12
# ...                          ...             ...                    ...
# 10454                          5              57                     21
# 10455                         39              68                     11
# 10456                          6              64                     18
# 10457                         12             113                     42
# 10458                          1              17                      4
#
#        NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 0                                3                            0
# 1                                4                            4
# 2                                0                            0
# 3                                1                            1
# 4                                0                            0
# ...                            ...                          ...
# 10454                            0                            0
# 10455                            0                            0
# 10456                            1                            1
# 10457                            2                            2
# 10458                            0                            0
#
#        PercentTradesNeverDelq  MSinceMostRecentDelq  ...  \
# 0                          83                     2  ...
# 1                         100                    -7  ...
# 2                         100                    -7  ...
# 3                          93                    76  ...
# 4                         100                    -7  ...
# ...                       ...                   ...  ...
# 10454                      95                    80  ...
# 10455                      92                    28  ...
# 10456                     100                    -7  ...
# 10457                      96                    35  ...
# 10458                     100                    -7  ...
#
#        PercentInstallTrades  MSinceMostRecentInqexcl7days  NumInqLast6M  \
# 0                        43                             0             0
# 1                        67                             0             0
# 2                        44                             0             4
# 3                        57                             0             5
# 4                        25                             0             1
# ...                     ...                           ...           ...
# 10454                    19                             7             0
# 10455                    42                             1             1
# 10456                    33                             3             4
# 10457                    20                             6             0
# 10458                    60                             3             3
#
#        NumInqLast6Mexcl7days  NetFractionRevolvingBurden  \
# 0                          0                          33
# 1                          0                           0
# 2                          4                          53
# 3                          4                          72
# 4                          1                          51
# ...                      ...                         ...
# 10454                      0                          26
# 10455                      1                          86
# 10456                      4                           6
# 10457                      0                          19
# 10458                      2                          67
#
#        NetFractionInstallBurden  NumRevolvingTradesWBalance  \
# 0                            -8                           8
# 1                            -8                           0
# 2                            66                           4
# 3                            83                           6
# 4                            89                           3
# ...                         ...                         ...
# 10454                        -8                           5
# 10455                        53                           2
# 10456                        -8                           5
# 10457                        -8                           4
# 10458                        -8                           2
#
#        NumInstallTradesWBalance  NumBank2NatlTradesWHighUtilization  \
# 0                             1                                   1
# 1                            -8                                  -8
# 2                             2                                   1
# 3                             4                                   3
# 4                             1                                   0
# ...                         ...                                 ...
# 10454                         2                                   0
# 10455                         2                                   1
# 10456                        -8                                   0
# 10457                         1                                   0
# 10458                         1                                   0
#
#        PercentTradesWBalance
# 0                         69
# 1                          0
# 2                         86
# 3                         91
# 4                         80
# ...                      ...
# 10454                    100
# 10455                     80
# 10456                     56
# 10457                     38
# 10458                    100
#
# [10459 rows x 24 columns]

# %%
mapping = {'Bad':0, 'Good':1}
data['RiskPerformance'] = data['RiskPerformance'].map(mapping)
x = data.iloc[:, 1:]
y = data.iloc[:, 0]
print(y)
print(x)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10454    1
# 10455    0
# 10456    0
# 10457    0
# 10458    0
# Name: RiskPerformance, Length: 10459, dtype: int64
#        ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 0                        55                    144                          4
# 1                        61                     58                         15
# 2                        67                     66                          5
# 3                        66                    169                          1
# 4                        81                    333                         27
# ...                     ...                    ...                        ...
# 10454                    73                    131                          5
# 10455                    65                    147                         39
# 10456                    74                    129                          6
# 10457                    72                    234                         12
# 10458                    66                     28                          1
#
#        AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# 0                  84                     20                            3
# 1                  41                      2                            4
# 2                  24                      9                            0
# 3                  73                     28                            1
# 4                 132                     12                            0
# ...               ...                    ...                          ...
# 10454              57                     21                            0
# 10455              68                     11                            0
# 10456              64                     18                            1
# 10457             113                     42                            2
# 10458              17                      4                            0
#
#        NumTrades90Ever2DerogPubRec  PercentTradesNeverDelq  \
# 0                                0                      83
# 1                                4                     100
# 2                                0                     100
# 3                                1                      93
# 4                                0                     100
# ...                            ...                     ...
# 10454                            0                      95
# 10455                            0                      92
# 10456                            1                     100
# 10457                            2                      96
# 10458                            0                     100
#
#        MSinceMostRecentDelq  MaxDelq2PublicRecLast12M  ...  \
# 0                         2                         3  ...
# 1                        -7                         0  ...
# 2                        -7                         7  ...
# 3                        76                         6  ...
# 4                        -7                         7  ...
# ...                     ...                       ...  ...
# 10454                    80                         6  ...
# 10455                    28                         6  ...
# 10456                    -7                         6  ...
# 10457                    35                         6  ...
# 10458                    -7                         7  ...
#
#        PercentInstallTrades  MSinceMostRecentInqexcl7days  NumInqLast6M  \
# 0                        43                             0             0
# 1                        67                             0             0
# 2                        44                             0             4
# 3                        57                             0             5
# 4                        25                             0             1
# ...                     ...                           ...           ...
# 10454                    19                             7             0
# 10455                    42                             1             1
# 10456                    33                             3             4
# 10457                    20                             6             0
# 10458                    60                             3             3
#
#        NumInqLast6Mexcl7days  NetFractionRevolvingBurden  \
# 0                          0                          33
# 1                          0                           0
# 2                          4                          53
# 3                          4                          72
# 4                          1                          51
# ...                      ...                         ...
# 10454                      0                          26
# 10455                      1                          86
# 10456                      4                           6
# 10457                      0                          19
# 10458                      2                          67
#
#        NetFractionInstallBurden  NumRevolvingTradesWBalance  \
# 0                            -8                           8
# 1                            -8                           0
# 2                            66                           4
# 3                            83                           6
# 4                            89                           3
# ...                         ...                         ...
# 10454                        -8                           5
# 10455                        53                           2
# 10456                        -8                           5
# 10457                        -8                           4
# 10458                        -8                           2
#
#        NumInstallTradesWBalance  NumBank2NatlTradesWHighUtilization  \
# 0                             1                                   1
# 1                            -8                                  -8
# 2                             2                                   1
# 3                             4                                   3
# 4                             1                                   0
# ...                         ...                                 ...
# 10454                         2                                   0
# 10455                         2                                   1
# 10456                        -8                                   0
# 10457                         1                                   0
# 10458                         1                                   0
#
#        PercentTradesWBalance
# 0                         69
# 1                          0
# 2                         86
# 3                         91
# 4                         80
# ...                      ...
# 10454                    100
# 10455                     80
# 10456                     56
# 10457                     38
# 10458                    100
#
# [10459 rows x 23 columns]

# %% [markdown]
# #### 2. bulid the training and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 2/3)

# %%
print(x_train, y_train)
# Out:
#        ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 4923                     84                    340                         16
# 3918                     76                    268                          1
# 5599                     88                    113                         25
# 343                      69                    124                         14
# 145                      59                     -8                          5
# ...                     ...                    ...                        ...
# 8852                     79                    120                          2
# 8987                     68                    222                          6
# 10113                    65                    116                          4
# 4394                     71                    522                         14
# 1346                     -9                     -9                         -9
#
#        AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# 4923               96                     14                            0
# 3918               78                     23                            0
# 5599               72                     14                            0
# 343                66                     20                            0
# 145                82                     20                            5
# ...               ...                    ...                          ...
# 8852               46                     22                            0
# 8987              103                     16                            1
# 10113              49                     14                            1
# 4394              159                     14                            1
# 1346               -9                     -9                           -9
#
#        NumTrades90Ever2DerogPubRec  PercentTradesNeverDelq  \
# 4923                             0                     100
# 3918                             0                     100
# 5599                             0                     100
# 343                              0                      95
# 145                              5                      78
# ...                            ...                     ...
# 8852                             0                     100
# 8987                             0                      84
# 10113                            1                      93
# 4394                             0                      88
# 1346                            -9                      -9
#
#        MSinceMostRecentDelq  MaxDelq2PublicRecLast12M  ...  \
# 4923                     -7                         7  ...
# 3918                     -7                         7  ...
# 5599                     -7                         7  ...
# 343                       3                         4  ...
# 145                       6                         4  ...
# ...                     ...                       ...  ...
# 8852                     -7                         7  ...
# 8987                     20                         5  ...
# 10113                     7                         1  ...
# 4394                     10                         4  ...
# 1346                     -9                        -9  ...
#
#        PercentInstallTrades  MSinceMostRecentInqexcl7days  NumInqLast6M  \
# 4923                     13                            -8             0
# 3918                     28                             0             2
# 5599                     21                             0             0
# 343                      60                             0             0
# 145                      67                             4             1
# ...                     ...                           ...           ...
# 8852                     22                             2             3
# 8987                     32                             0             0
# 10113                    27                            -7             4
# 4394                     38                             0             0
# 1346                     -9                            -9            -9
#
#        NumInqLast6Mexcl7days  NetFractionRevolvingBurden  \
# 4923                       0                          28
# 3918                       2                          13
# 5599                       0                           4
# 343                        0                          58
# 145                        1                          98
# ...                      ...                         ...
# 8852                       3                           6
# 8987                       0                          59
# 10113                      4                          25
# 4394                       0                          44
# 1346                      -9                          -9
#
#        NetFractionInstallBurden  NumRevolvingTradesWBalance  \
# 4923                         -8                           3
# 3918                         53                           4
# 5599                         -8                           1
# 343                          73                           3
# 145                          84                           2
# ...                         ...                         ...
# 8852                         90                           1
# 8987                         -8                           5
# 10113                        17                           2
# 4394                         77                           5
# 1346                         -9                          -9
#
#        NumInstallTradesWBalance  NumBank2NatlTradesWHighUtilization  \
# 4923                          1                                   0
# 3918                          2                                   0
# 5599                          1                                   0
# 343                           3                                   1
# 145                           4                                  -8
# ...                         ...                                 ...
# 8852                          2                                   0
# 8987                         -8                                   3
# 10113                         2                                   0
# 4394                          2                                   1
# 1346                         -9                                  -9
#
#        PercentTradesWBalance
# 4923                      67
# 3918                      43
# 5599                      25
# 343                       86
# 145                      100
# ...                      ...
# 8852                      50
# 8987                      63
# 10113                     44
# 4394                      88
# 1346                      -9
#
# [3486 rows x 23 columns] 4923     1
# 3918     1
# 5599     1
# 343      0
# 145      0
#         ..
# 8852     1
# 8987     0
# 10113    1
# 4394     1
# 1346     0
# Name: RiskPerformance, Length: 3486, dtype: int64

# %% [markdown]
# #### 3. bulid our model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
train_score = model.score(x_train,y_train)
# Out:
# F:\Users\zhuxu\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# #### 4. training and test results

# %%
print('Coeffocient: \n', model.coef_)
test_score = model.score(x_test,y_test)
print('train score:{train_score: .6f}; test score:{test_score:.6f}'.format(train_score=train_score,test_score=test_score))
 
# 查看预测样本中有几个正确
y_pred = model.predict(x_test)
# sum()只返回True的个数
print('matchs:{0}/{1}'.format(np.equal(y_pred,y_test).sum(), y_test.shape[0]))
# Out:
# Coeffocient:
#  [[ 0.03643253  0.0004035  -0.00300736  0.00826187  0.03816407 -0.25345387
#    0.07164827  0.00752542 -0.00195518  0.06346382 -0.0582933  -0.00100242
#   -0.06376019 -0.01815685  0.03051522 -0.17880442  0.10203607 -0.01154507
#   -0.00058053 -0.13843772  0.0329493   0.01210009  0.00169039]]
# train score: 0.714573; test score:0.712319
# matchs:4967/6973
