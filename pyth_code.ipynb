# %% [markdown]
# ## logistics model

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. import the data

# %%
data = pd.read_csv('heloc_dataset_v1.csv')
print(data)
# Out:
#       RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0                 Bad                    55                    144
# 1                 Bad                    61                     58
# 2                 Bad                    67                     66
# 3                 Bad                    66                    169
# 4                 Bad                    81                    333
# ...               ...                   ...                    ...
# 10454            Good                    73                    131
# 10455             Bad                    65                    147
# 10456             Bad                    74                    129
# 10457             Bad                    72                    234
# 10458             Bad                    66                     28
#
#        MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                              4              84                     20
# 1                             15              41                      2
# 2                              5              24                      9
# 3                              1              73                     28
# 4                             27             132                     12
# ...                          ...             ...                    ...
# 10454                          5              57                     21
# 10455                         39              68                     11
# 10456                          6              64                     18
# 10457                         12             113                     42
# 10458                          1              17                      4
#
#        NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 0                                3                            0
# 1                                4                            4
# 2                                0                            0
# 3                                1                            1
# 4                                0                            0
# ...                            ...                          ...
# 10454                            0                            0
# 10455                            0                            0
# 10456                            1                            1
# 10457                            2                            2
# 10458                            0                            0
#
#        PercentTradesNeverDelq  MSinceMostRecentDelq  ...  \
# 0                          83                     2  ...
# 1                         100                    -7  ...
# 2                         100                    -7  ...
# 3                          93                    76  ...
# 4                         100                    -7  ...
# ...                       ...                   ...  ...
# 10454                      95                    80  ...
# 10455                      92                    28  ...
# 10456                     100                    -7  ...
# 10457                      96                    35  ...
# 10458                     100                    -7  ...
#
#        PercentInstallTrades  MSinceMostRecentInqexcl7days  NumInqLast6M  \
# 0                        43                             0             0
# 1                        67                             0             0
# 2                        44                             0             4
# 3                        57                             0             5
# 4                        25                             0             1
# ...                     ...                           ...           ...
# 10454                    19                             7             0
# 10455                    42                             1             1
# 10456                    33                             3             4
# 10457                    20                             6             0
# 10458                    60                             3             3
#
#        NumInqLast6Mexcl7days  NetFractionRevolvingBurden  \
# 0                          0                          33
# 1                          0                           0
# 2                          4                          53
# 3                          4                          72
# 4                          1                          51
# ...                      ...                         ...
# 10454                      0                          26
# 10455                      1                          86
# 10456                      4                           6
# 10457                      0                          19
# 10458                      2                          67
#
#        NetFractionInstallBurden  NumRevolvingTradesWBalance  \
# 0                            -8                           8
# 1                            -8                           0
# 2                            66                           4
# 3                            83                           6
# 4                            89                           3
# ...                         ...                         ...
# 10454                        -8                           5
# 10455                        53                           2
# 10456                        -8                           5
# 10457                        -8                           4
# 10458                        -8                           2
#
#        NumInstallTradesWBalance  NumBank2NatlTradesWHighUtilization  \
# 0                             1                                   1
# 1                            -8                                  -8
# 2                             2                                   1
# 3                             4                                   3
# 4                             1                                   0
# ...                         ...                                 ...
# 10454                         2                                   0
# 10455                         2                                   1
# 10456                        -8                                   0
# 10457                         1                                   0
# 10458                         1                                   0
#
#        PercentTradesWBalance
# 0                         69
# 1                          0
# 2                         86
# 3                         91
# 4                         80
# ...                      ...
# 10454                    100
# 10455                     80
# 10456                     56
# 10457                     38
# 10458                    100
#
# [10459 rows x 24 columns]

# %%
mapping = {'Bad':0, 'Good':1}
data['RiskPerformance'] = data['RiskPerformance'].map(mapping)
x = data.iloc[:, 1:]
y = data.iloc[:, 0]
print(y)
print(x)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10454    1
# 10455    0
# 10456    0
# 10457    0
# 10458    0
# Name: RiskPerformance, Length: 10459, dtype: int64
#        ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 0                        55                    144                          4
# 1                        61                     58                         15
# 2                        67                     66                          5
# 3                        66                    169                          1
# 4                        81                    333                         27
# ...                     ...                    ...                        ...
# 10454                    73                    131                          5
# 10455                    65                    147                         39
# 10456                    74                    129                          6
# 10457                    72                    234                         12
# 10458                    66                     28                          1
#
#        AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# 0                  84                     20                            3
# 1                  41                      2                            4
# 2                  24                      9                            0
# 3                  73                     28                            1
# 4                 132                     12                            0
# ...               ...                    ...                          ...
# 10454              57                     21                            0
# 10455              68                     11                            0
# 10456              64                     18                            1
# 10457             113                     42                            2
# 10458              17                      4                            0
#
#        NumTrades90Ever2DerogPubRec  PercentTradesNeverDelq  \
# 0                                0                      83
# 1                                4                     100
# 2                                0                     100
# 3                                1                      93
# 4                                0                     100
# ...                            ...                     ...
# 10454                            0                      95
# 10455                            0                      92
# 10456                            1                     100
# 10457                            2                      96
# 10458                            0                     100
#
#        MSinceMostRecentDelq  MaxDelq2PublicRecLast12M  ...  \
# 0                         2                         3  ...
# 1                        -7                         0  ...
# 2                        -7                         7  ...
# 3                        76                         6  ...
# 4                        -7                         7  ...
# ...                     ...                       ...  ...
# 10454                    80                         6  ...
# 10455                    28                         6  ...
# 10456                    -7                         6  ...
# 10457                    35                         6  ...
# 10458                    -7                         7  ...
#
#        PercentInstallTrades  MSinceMostRecentInqexcl7days  NumInqLast6M  \
# 0                        43                             0             0
# 1                        67                             0             0
# 2                        44                             0             4
# 3                        57                             0             5
# 4                        25                             0             1
# ...                     ...                           ...           ...
# 10454                    19                             7             0
# 10455                    42                             1             1
# 10456                    33                             3             4
# 10457                    20                             6             0
# 10458                    60                             3             3
#
#        NumInqLast6Mexcl7days  NetFractionRevolvingBurden  \
# 0                          0                          33
# 1                          0                           0
# 2                          4                          53
# 3                          4                          72
# 4                          1                          51
# ...                      ...                         ...
# 10454                      0                          26
# 10455                      1                          86
# 10456                      4                           6
# 10457                      0                          19
# 10458                      2                          67
#
#        NetFractionInstallBurden  NumRevolvingTradesWBalance  \
# 0                            -8                           8
# 1                            -8                           0
# 2                            66                           4
# 3                            83                           6
# 4                            89                           3
# ...                         ...                         ...
# 10454                        -8                           5
# 10455                        53                           2
# 10456                        -8                           5
# 10457                        -8                           4
# 10458                        -8                           2
#
#        NumInstallTradesWBalance  NumBank2NatlTradesWHighUtilization  \
# 0                             1                                   1
# 1                            -8                                  -8
# 2                             2                                   1
# 3                             4                                   3
# 4                             1                                   0
# ...                         ...                                 ...
# 10454                         2                                   0
# 10455                         2                                   1
# 10456                        -8                                   0
# 10457                         1                                   0
# 10458                         1                                   0
#
#        PercentTradesWBalance
# 0                         69
# 1                          0
# 2                         86
# 3                         91
# 4                         80
# ...                      ...
# 10454                    100
# 10455                     80
# 10456                     56
# 10457                     38
# 10458                    100
#
# [10459 rows x 23 columns]

# %% [markdown]
# #### 2. bulid the training and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 2/3)

# %%
print(x_train, y_train)
# Out:
#       ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 5785                    -9                     -9                         -9
# 1613                    66                    340                         11
# 7527                    83                    166                          2
# 1535                    67                     62                          8
# 6618                    89                    379                        156
# ...                    ...                    ...                        ...
# 5557                    68                    176                         10
# 1949                    59                    168                          3
# 4543                    67                    214                          2
# 246                     61                    251                         12
# 7506                    55                    205                         22
#
#       AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# 5785              -9                     -9                           -9
# 1613             117                     36                            0
# 7527              65                     18                            0
# 1535              32                     10                            0
# 6618             257                      3                            0
# ...              ...                    ...                          ...
# 5557              98                     21                            0
# 1949              38                     21                            0
# 4543              76                     31                            1
# 246               74                     15                            0
# 7506             147                     10                            4
#
#       NumTrades90Ever2DerogPubRec  PercentTradesNeverDelq  \
# 5785                           -9                      -9
# 1613                            0                     100
# 7527                            0                      95
# 1535                            0                     100
# 6618                            0                     100
# ...                           ...                     ...
# 5557                            0                      81
# 1949                            0                     100
# 4543                            1                     100
# 246                             0                      93
# 7506                            4                      83
#
#       MSinceMostRecentDelq  MaxDelq2PublicRecLast12M  ...  \
# 5785                    -9                        -9  ...
# 1613                    -7                         7  ...
# 7527                    57                         6  ...
# 1535                    -7                         7  ...
# 6618                    -7                         7  ...
# ...                    ...                       ...  ...
# 5557                    44                         6  ...
# 1949                    -7                         7  ...
# 4543                    -7                         7  ...
# 246                     70                         6  ...
# 7506                    10                         1  ...
#
#       PercentInstallTrades  MSinceMostRecentInqexcl7days  NumInqLast6M  \
# 5785                    -9                            -9            -9
# 1613                    11                             0             0
# 7527                    32                            -7             1
# 1535                    40                             0             2
# 6618                    33                            -7             0
# ...                    ...                           ...           ...
# 5557                    33                            10             0
# 1949                    38                             0             1
# 4543                    13                            -7             0
# 246                     13                             0             1
# 7506                    33                            -7             2
#
#       NumInqLast6Mexcl7days  NetFractionRevolvingBurden  \
# 5785                     -9                          -9
# 1613                      0                          81
# 7527                      1                          12
# 1535                      2                          89
# 6618                      0                           0
# ...                     ...                         ...
# 5557                      0                          76
# 1949                      1                          85
# 4543                      0                          11
# 246                       1                          89
# 7506                      2                          99
#
#       NetFractionInstallBurden  NumRevolvingTradesWBalance  \
# 5785                        -9                          -9
# 1613                        -8                          20
# 7527                        64                           2
# 1535                        49                           5
# 6618                        -8                           0
# ...                        ...                         ...
# 5557                        -8                           4
# 1949                        90                          10
# 4543                        -8                           6
# 246                         -8                           7
# 7506                        70                           2
#
#       NumInstallTradesWBalance  NumBank2NatlTradesWHighUtilization  \
# 5785                        -9                                  -9
# 1613                         1                                  11
# 7527                         3                                   0
# 1535                         3                                   2
# 6618                        -8                                  -8
# ...                        ...                                 ...
# 5557                        -8                                   1
# 1949                         5                                   4
# 4543                         1                                   0
# 246                          1                                   5
# 7506                         2                                   2
#
#       PercentTradesWBalance
# 5785                     -9
# 1613                     75
# 7527                     63
# 1535                    100
# 6618                      0
# ...                     ...
# 5557                     80
# 1949                     94
# 4543                     37
# 246                     100
# 7506                    100
#
# [3486 rows x 23 columns] 5785    1
# 1613    0
# 7527    1
# 1535    0
# 6618    1
#        ..
# 5557    1
# 1949    0
# 4543    1
# 246     0
# 7506    0
# Name: RiskPerformance, Length: 3486, dtype: int64

# %% [markdown]
# #### 3. bulid our model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
train_score = model.score(x_train,y_train)
# Out:
# F:\Users\zhuxu\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# #### 4. training and test results

# %%
print('Coeffocient: \n', model.coef_)
test_score = model.score(x_test,y_test)
print('train score:{train_score: .6f}; test score:{test_score:.6f}'.format(train_score=train_score,test_score=test_score))
 
# 查看预测样本中有几个正确
y_pred = model.predict(x_test)
# sum()只返回True的个数
print('matchs:{0}/{1}'.format(np.equal(y_pred,y_test).sum(), y_test.shape[0]))
# Out:
# Coeffocient:
#  [[ 3.06135680e-02  5.03386614e-04 -9.80039550e-03  9.48293383e-03
#    3.00499217e-02 -1.99141251e-01  2.78406119e-03  8.28603543e-03
#    2.36614596e-04  7.94442025e-02 -2.61827951e-02  3.22954138e-04
#   -5.49974365e-02 -1.55726444e-02  3.34121737e-02 -4.12513102e-01
#    3.16733134e-01 -1.32883885e-02  8.50373624e-05 -9.94711668e-02
#    6.33018167e-03  2.60708363e-02 -2.01161481e-03]]
# train score: 0.721744; test score:0.714614
# matchs:4983/6973
